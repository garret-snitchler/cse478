# %%
import tensorflow as tf
from model import create_model_one, build_model_two
from util import load_preprocess_data, plot_history, plot_conf_matrix
import numpy as np


print("loading data")
(train_x, train_y), (val_x, val_y), (test_x, test_y) = load_preprocess_data()


num_classes = 100
input_shape = (32, 32, 3)

class_names = [str(i) for i in range(num_classes)]
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
top5 = tf.keras.metrics.SparseTopKCategoricalAccuracy(
    k=5, name="sparse_top_5_categorical_accuracy", dtype=None
)

#building models
print("Training model1 with adam\n")
model1 = create_model_one(input_shape=input_shape, num_classes=num_classes)
model1.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy',
               metrics=[top5])
history1 = model1.fit(train_x, train_y, epochs=50, batch_size=64, 
                      validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history1, 'Model1 Adam')

print("\nTraining model1 with sgd\n")
model1_sgd = create_model_one(input_shape=input_shape, num_classes=num_classes)
model1_sgd.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
                   loss='sparse_categorical_crossentropy',
                   metrics=[top5])
history1_sgd = model1_sgd.fit(train_x, train_y, epochs=50, batch_size=64, 
                              validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history1_sgd, 'Model1 SGD')

#testing best models
print("\nEvaluating best models")
test_loss, test_acc = model1.evaluate(test_x, test_y)
print(f"Test accuracy: {test_acc:.4f}")

print("\nMaking predictions / plotting confusion matrix")
y_pred = np.argmax(model1.predict(test_x), axis=1)
plot_conf_matrix(test_y, y_pred, class_names)

#second model adam

print("\nTraining model2 with adam \n")
model2 = build_model_two(input_shape=input_shape, num_classes=num_classes)
model2.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy',
               metrics=[top5])
history2 = model2.fit(train_x, train_y, epochs=50, batch_size=64, 
                      validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history2, 'Model2 Adam')

print("\nTraining model2 with sgd\n")
model2_sgd = build_model_two(input_shape=input_shape, num_classes=num_classes)
model2_sgd.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
                   loss='sparse_categorical_crossentropy',
                   metrics=[top5])
history2_sgd = model2_sgd.fit(train_x, train_y, epochs=50, batch_size=64, 
                              validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history2_sgd, 'Model2 SGD')

#testing best models
print("\nEvaluating best models")
test_loss, test_acc = model2.evaluate(test_x, test_y)
print(f"Test accuracy: {test_acc:.4f}")


print("\nMaking predictions / plotting confusion matrix")
y_pred = np.argmax(model2.predict(test_x), axis=1)
plot_conf_matrix(test_y, y_pred, class_names)
# Out:
# 2025-07-11 10:05:00.156357: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2025-07-11 10:05:00.599230: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data
# Loading CIFAR100 data
# Validation size: 5000
# Train shape: (45000, 32, 32, 3)
# Val shape:  (5000, 32, 32, 3)
# test shape: (10000, 32, 32, 3)
# Training model1 with adam
# 2025-07-11 10:06:19.938709: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :
# 2025-07-11 10:06:19.938737: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-07-11 10:06:19.938753: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c1408.swan.hcc.unl.edu): /proc/driver/nvidia/version does not exist
# 2025-07-11 10:06:19.939019: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-11 10:06:19.956893: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2600000000 Hz
# 2025-07-11 10:06:19.957497: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558c6a7d2c60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-07-11 10:06:19.957513: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Epoch 1/50
# 704/704 [==============================] - 6s 9ms/step - loss: 4.3191 - sparse_top_5_categorical_accuracy: 0.1746 - val_loss: 4.0694 - val_sparse_top_5_categorical_accuracy: 0.2778
# Epoch 2/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.9341 - sparse_top_5_categorical_accuracy: 0.3050 - val_loss: 3.6297 - val_sparse_top_5_categorical_accuracy: 0.4258
# Epoch 3/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.7806 - sparse_top_5_categorical_accuracy: 0.3574 - val_loss: 3.4844 - val_sparse_top_5_categorical_accuracy: 0.4732
# Epoch 4/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.7017 - sparse_top_5_categorical_accuracy: 0.3820 - val_loss: 3.3996 - val_sparse_top_5_categorical_accuracy: 0.4898
# Epoch 5/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.6406 - sparse_top_5_categorical_accuracy: 0.4035 - val_loss: 3.3373 - val_sparse_top_5_categorical_accuracy: 0.5172
# Epoch 6/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.5761 - sparse_top_5_categorical_accuracy: 0.4264 - val_loss: 3.2274 - val_sparse_top_5_categorical_accuracy: 0.5470
# Epoch 7/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.5303 - sparse_top_5_categorical_accuracy: 0.4386 - val_loss: 3.2132 - val_sparse_top_5_categorical_accuracy: 0.5606
# Epoch 8/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.5034 - sparse_top_5_categorical_accuracy: 0.4477 - val_loss: 3.1896 - val_sparse_top_5_categorical_accuracy: 0.5628
# Epoch 9/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.4616 - sparse_top_5_categorical_accuracy: 0.4580 - val_loss: 3.1730 - val_sparse_top_5_categorical_accuracy: 0.5714
# Epoch 10/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.4430 - sparse_top_5_categorical_accuracy: 0.4632 - val_loss: 3.1855 - val_sparse_top_5_categorical_accuracy: 0.5780
# Epoch 11/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.4204 - sparse_top_5_categorical_accuracy: 0.4702 - val_loss: 3.0545 - val_sparse_top_5_categorical_accuracy: 0.5948
# Epoch 12/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3968 - sparse_top_5_categorical_accuracy: 0.4756 - val_loss: 3.1146 - val_sparse_top_5_categorical_accuracy: 0.5892
# Epoch 13/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3795 - sparse_top_5_categorical_accuracy: 0.4821 - val_loss: 3.0797 - val_sparse_top_5_categorical_accuracy: 0.5974
# Epoch 14/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3559 - sparse_top_5_categorical_accuracy: 0.4897 - val_loss: 3.0263 - val_sparse_top_5_categorical_accuracy: 0.5994
# Epoch 15/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3350 - sparse_top_5_categorical_accuracy: 0.4951 - val_loss: 3.0351 - val_sparse_top_5_categorical_accuracy: 0.6012
# Epoch 16/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3236 - sparse_top_5_categorical_accuracy: 0.4979 - val_loss: 3.0218 - val_sparse_top_5_categorical_accuracy: 0.6012
# Epoch 17/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3074 - sparse_top_5_categorical_accuracy: 0.5033 - val_loss: 3.0061 - val_sparse_top_5_categorical_accuracy: 0.6164
# Epoch 18/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2881 - sparse_top_5_categorical_accuracy: 0.5099 - val_loss: 2.9812 - val_sparse_top_5_categorical_accuracy: 0.6128
# Epoch 19/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2818 - sparse_top_5_categorical_accuracy: 0.5114 - val_loss: 2.9804 - val_sparse_top_5_categorical_accuracy: 0.6126
# Epoch 20/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2689 - sparse_top_5_categorical_accuracy: 0.5142 - val_loss: 2.9845 - val_sparse_top_5_categorical_accuracy: 0.6162
# Epoch 21/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2618 - sparse_top_5_categorical_accuracy: 0.5164 - val_loss: 2.9609 - val_sparse_top_5_categorical_accuracy: 0.6152
# Epoch 22/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2516 - sparse_top_5_categorical_accuracy: 0.5170 - val_loss: 2.9436 - val_sparse_top_5_categorical_accuracy: 0.6124
# Epoch 23/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2380 - sparse_top_5_categorical_accuracy: 0.5232 - val_loss: 2.9599 - val_sparse_top_5_categorical_accuracy: 0.6134
# Epoch 24/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2250 - sparse_top_5_categorical_accuracy: 0.5284 - val_loss: 2.8988 - val_sparse_top_5_categorical_accuracy: 0.6270
# Epoch 25/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2162 - sparse_top_5_categorical_accuracy: 0.5319 - val_loss: 2.9520 - val_sparse_top_5_categorical_accuracy: 0.6150
# Epoch 26/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2109 - sparse_top_5_categorical_accuracy: 0.5337 - val_loss: 2.9480 - val_sparse_top_5_categorical_accuracy: 0.6246
# Epoch 27/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.1983 - sparse_top_5_categorical_accuracy: 0.5332 - val_loss: 2.9579 - val_sparse_top_5_categorical_accuracy: 0.6120
# Epoch 28/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2003 - sparse_top_5_categorical_accuracy: 0.5356 - val_loss: 2.9575 - val_sparse_top_5_categorical_accuracy: 0.6184
# Epoch 29/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.1853 - sparse_top_5_categorical_accuracy: 0.5386 - val_loss: 2.8994 - val_sparse_top_5_categorical_accuracy: 0.6278
# Training model1 with sgd
#
# Epoch 1/50
# 704/704 [==============================] - 6s 9ms/step - loss: 4.6312 - sparse_top_5_categorical_accuracy: 0.1834 - val_loss: 4.2252 - val_sparse_top_5_categorical_accuracy: 0.2700
# Epoch 2/50
# 704/704 [==============================] - 6s 9ms/step - loss: 4.1659 - sparse_top_5_categorical_accuracy: 0.2750 - val_loss: 3.8886 - val_sparse_top_5_categorical_accuracy: 0.3782
# Epoch 3/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.8827 - sparse_top_5_categorical_accuracy: 0.3566 - val_loss: 3.5714 - val_sparse_top_5_categorical_accuracy: 0.4570
# Epoch 4/50
# 704/704 [==============================] - 6s 8ms/step - loss: 3.6747 - sparse_top_5_categorical_accuracy: 0.4134 - val_loss: 3.3648 - val_sparse_top_5_categorical_accuracy: 0.5128
# Epoch 5/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.5056 - sparse_top_5_categorical_accuracy: 0.4586 - val_loss: 3.2094 - val_sparse_top_5_categorical_accuracy: 0.5534
# Epoch 6/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.3765 - sparse_top_5_categorical_accuracy: 0.4946 - val_loss: 3.1411 - val_sparse_top_5_categorical_accuracy: 0.5726
# Epoch 7/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.2750 - sparse_top_5_categorical_accuracy: 0.5205 - val_loss: 3.0444 - val_sparse_top_5_categorical_accuracy: 0.5998
# Epoch 8/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.1695 - sparse_top_5_categorical_accuracy: 0.5529 - val_loss: 2.9042 - val_sparse_top_5_categorical_accuracy: 0.6272
# Epoch 9/50
# 704/704 [==============================] - 6s 8ms/step - loss: 3.0801 - sparse_top_5_categorical_accuracy: 0.5746 - val_loss: 2.8928 - val_sparse_top_5_categorical_accuracy: 0.6326
# Epoch 10/50
# 704/704 [==============================] - 6s 9ms/step - loss: 3.0148 - sparse_top_5_categorical_accuracy: 0.5958 - val_loss: 2.8528 - val_sparse_top_5_categorical_accuracy: 0.6438
# Epoch 11/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.9555 - sparse_top_5_categorical_accuracy: 0.6122 - val_loss: 2.8663 - val_sparse_top_5_categorical_accuracy: 0.6422
# Epoch 12/50
# 704/704 [==============================] - 6s 8ms/step - loss: 2.8954 - sparse_top_5_categorical_accuracy: 0.6324 - val_loss: 2.7917 - val_sparse_top_5_categorical_accuracy: 0.6572
# Epoch 13/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.8461 - sparse_top_5_categorical_accuracy: 0.6467 - val_loss: 2.8499 - val_sparse_top_5_categorical_accuracy: 0.6454
# Epoch 14/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.7853 - sparse_top_5_categorical_accuracy: 0.6629 - val_loss: 2.7743 - val_sparse_top_5_categorical_accuracy: 0.6710
# Epoch 15/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.7632 - sparse_top_5_categorical_accuracy: 0.6710 - val_loss: 2.7610 - val_sparse_top_5_categorical_accuracy: 0.6812
# Epoch 16/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.7119 - sparse_top_5_categorical_accuracy: 0.6881 - val_loss: 2.7755 - val_sparse_top_5_categorical_accuracy: 0.6770
# Epoch 17/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.6886 - sparse_top_5_categorical_accuracy: 0.6973 - val_loss: 2.7816 - val_sparse_top_5_categorical_accuracy: 0.6814
# Epoch 18/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.6700 - sparse_top_5_categorical_accuracy: 0.7065 - val_loss: 2.8061 - val_sparse_top_5_categorical_accuracy: 0.6788
# Epoch 19/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.6421 - sparse_top_5_categorical_accuracy: 0.7154 - val_loss: 2.8131 - val_sparse_top_5_categorical_accuracy: 0.6848
# Epoch 20/50
# 704/704 [==============================] - 6s 9ms/step - loss: 2.6218 - sparse_top_5_categorical_accuracy: 0.7259 - val_loss: 2.8453 - val_sparse_top_5_categorical_accuracy: 0.6810
# Evaluating best models
# 313/313 [==============================] - 0s 1ms/step - loss: 2.8939 - sparse_top_5_categorical_accuracy: 0.6334
# Test accuracy: 0.6334
#
# Making predictions / plotting confusion matrix
# Training model2 with adam
#
# Epoch 1/50
# 704/704 [==============================] - 13s 19ms/step - loss: 4.2211 - sparse_top_5_categorical_accuracy: 0.2876 - val_loss: 3.7575 - val_sparse_top_5_categorical_accuracy: 0.3708
# Epoch 2/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.6608 - sparse_top_5_categorical_accuracy: 0.4010 - val_loss: 3.3450 - val_sparse_top_5_categorical_accuracy: 0.5036
# Epoch 3/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.3707 - sparse_top_5_categorical_accuracy: 0.4925 - val_loss: 3.1076 - val_sparse_top_5_categorical_accuracy: 0.5776
# Epoch 4/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.1896 - sparse_top_5_categorical_accuracy: 0.5468 - val_loss: 2.9889 - val_sparse_top_5_categorical_accuracy: 0.6040
# Epoch 5/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.0490 - sparse_top_5_categorical_accuracy: 0.5842 - val_loss: 2.8249 - val_sparse_top_5_categorical_accuracy: 0.6390
# Epoch 6/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.9471 - sparse_top_5_categorical_accuracy: 0.6122 - val_loss: 2.8197 - val_sparse_top_5_categorical_accuracy: 0.6334
# Epoch 7/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.8469 - sparse_top_5_categorical_accuracy: 0.6350 - val_loss: 2.7009 - val_sparse_top_5_categorical_accuracy: 0.6718
# Epoch 8/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.7817 - sparse_top_5_categorical_accuracy: 0.6521 - val_loss: 2.7039 - val_sparse_top_5_categorical_accuracy: 0.6750
# Epoch 9/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.7076 - sparse_top_5_categorical_accuracy: 0.6699 - val_loss: 2.6080 - val_sparse_top_5_categorical_accuracy: 0.6976
# Epoch 10/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.6487 - sparse_top_5_categorical_accuracy: 0.6828 - val_loss: 2.5673 - val_sparse_top_5_categorical_accuracy: 0.6968
# Epoch 11/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.5951 - sparse_top_5_categorical_accuracy: 0.6979 - val_loss: 2.6318 - val_sparse_top_5_categorical_accuracy: 0.6914
# Epoch 12/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.5461 - sparse_top_5_categorical_accuracy: 0.7114 - val_loss: 2.5457 - val_sparse_top_5_categorical_accuracy: 0.7080
# Epoch 13/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.5113 - sparse_top_5_categorical_accuracy: 0.7175 - val_loss: 2.5047 - val_sparse_top_5_categorical_accuracy: 0.7206
# Epoch 14/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.4640 - sparse_top_5_categorical_accuracy: 0.7274 - val_loss: 2.5549 - val_sparse_top_5_categorical_accuracy: 0.7106
# Epoch 15/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.4341 - sparse_top_5_categorical_accuracy: 0.7349 - val_loss: 2.4705 - val_sparse_top_5_categorical_accuracy: 0.7310
# Epoch 16/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3896 - sparse_top_5_categorical_accuracy: 0.7454 - val_loss: 2.5282 - val_sparse_top_5_categorical_accuracy: 0.7188
# Epoch 17/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3664 - sparse_top_5_categorical_accuracy: 0.7508 - val_loss: 2.4991 - val_sparse_top_5_categorical_accuracy: 0.7220
# Epoch 18/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3373 - sparse_top_5_categorical_accuracy: 0.7579 - val_loss: 2.5334 - val_sparse_top_5_categorical_accuracy: 0.7206
# Epoch 19/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3103 - sparse_top_5_categorical_accuracy: 0.7654 - val_loss: 2.4935 - val_sparse_top_5_categorical_accuracy: 0.7176
# Epoch 20/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.2840 - sparse_top_5_categorical_accuracy: 0.7686 - val_loss: 2.5042 - val_sparse_top_5_categorical_accuracy: 0.7268
# Training model2 with sgd
#
# Epoch 1/50
# 704/704 [==============================] - 13s 19ms/step - loss: 4.8036 - sparse_top_5_categorical_accuracy: 0.1930 - val_loss: 4.4026 - val_sparse_top_5_categorical_accuracy: 0.2476
# Epoch 2/50
# 704/704 [==============================] - 13s 19ms/step - loss: 4.2603 - sparse_top_5_categorical_accuracy: 0.2869 - val_loss: 3.9676 - val_sparse_top_5_categorical_accuracy: 0.3666
# Epoch 3/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.8902 - sparse_top_5_categorical_accuracy: 0.3843 - val_loss: 3.5659 - val_sparse_top_5_categorical_accuracy: 0.4738
# Epoch 4/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.5870 - sparse_top_5_categorical_accuracy: 0.4610 - val_loss: 3.3322 - val_sparse_top_5_categorical_accuracy: 0.5434
# Epoch 5/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.3447 - sparse_top_5_categorical_accuracy: 0.5201 - val_loss: 3.1152 - val_sparse_top_5_categorical_accuracy: 0.5836
# Epoch 6/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.1508 - sparse_top_5_categorical_accuracy: 0.5660 - val_loss: 2.9268 - val_sparse_top_5_categorical_accuracy: 0.6202
# Epoch 7/50
# 704/704 [==============================] - 13s 19ms/step - loss: 3.0016 - sparse_top_5_categorical_accuracy: 0.6027 - val_loss: 2.8540 - val_sparse_top_5_categorical_accuracy: 0.6462
# Epoch 8/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.8644 - sparse_top_5_categorical_accuracy: 0.6333 - val_loss: 2.7466 - val_sparse_top_5_categorical_accuracy: 0.6714
# Epoch 9/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.7465 - sparse_top_5_categorical_accuracy: 0.6653 - val_loss: 2.7340 - val_sparse_top_5_categorical_accuracy: 0.6672
# Epoch 10/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.6421 - sparse_top_5_categorical_accuracy: 0.6906 - val_loss: 2.6922 - val_sparse_top_5_categorical_accuracy: 0.6782
# Epoch 11/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.5603 - sparse_top_5_categorical_accuracy: 0.7118 - val_loss: 2.6414 - val_sparse_top_5_categorical_accuracy: 0.7060
# Epoch 12/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.4720 - sparse_top_5_categorical_accuracy: 0.7327 - val_loss: 2.5781 - val_sparse_top_5_categorical_accuracy: 0.7112
# Epoch 13/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.4117 - sparse_top_5_categorical_accuracy: 0.7501 - val_loss: 2.5688 - val_sparse_top_5_categorical_accuracy: 0.7152
# Epoch 14/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3484 - sparse_top_5_categorical_accuracy: 0.7666 - val_loss: 2.5769 - val_sparse_top_5_categorical_accuracy: 0.7288
# Epoch 15/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.2992 - sparse_top_5_categorical_accuracy: 0.7814 - val_loss: 2.6287 - val_sparse_top_5_categorical_accuracy: 0.7204
# Epoch 16/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.2643 - sparse_top_5_categorical_accuracy: 0.7943 - val_loss: 2.6246 - val_sparse_top_5_categorical_accuracy: 0.7284
# Epoch 17/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.2112 - sparse_top_5_categorical_accuracy: 0.8095 - val_loss: 2.6597 - val_sparse_top_5_categorical_accuracy: 0.7210
# Epoch 18/50
# 704/704 [==============================] - 13s 19ms/step - loss: 2.1812 - sparse_top_5_categorical_accuracy: 0.8173 - val_loss: 2.6852 - val_sparse_top_5_categorical_accuracy: 0.7202
# Evaluating best models
# 313/313 [==============================] - 1s 3ms/step - loss: 2.4594 - sparse_top_5_categorical_accuracy: 0.7338
# Test accuracy: 0.7338
#
# Making predictions / plotting confusion matrix
