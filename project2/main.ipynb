# %%
import tensorflow as tf
from model import create_model_one, build_model_two
from util import load_preprocess_data, plot_history, plot_conf_matrix
import numpy as np


print("loading data")
(train_x, train_y), (val_x, val_y), (test_x, test_y) = load_preprocess_data()


num_classes = 100
input_shape = (32, 32, 3)

class_names = [str(i) for i in range(num_classes)]
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
top5 = tf.keras.metrics.SparseTopKCategoricalAccuracy(
    k=5, name="sparse_top_5_categorical_accuracy", dtype=None
)

#building models
print("Training model1 with adam\n")
model1 = create_model_one(input_shape=input_shape, num_classes=num_classes)
model1.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy',
               metrics=[top5])
history1 = model1.fit(train_x, train_y, epochs=50, batch_size=64, 
                      validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history1, 'Model1 Adam')

print("\nTraining model1 with sgd\n")
model1_sgd = create_model_one(input_shape=input_shape, num_classes=num_classes)
model1_sgd.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
                   loss='sparse_categorical_crossentropy',
                   metrics=[top5])
history1_sgd = model1_sgd.fit(train_x, train_y, epochs=50, batch_size=64, 
                              validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history1_sgd, 'Model1 SGD')

#testing best models
print("\nEvaluating best models")
test_loss, test_acc = model1.evaluate(test_x, test_y)
print(f"Test accuracy: {test_acc:.4f}")

#second model adam

print("\nTraining model2 with adam \n")
model2 = build_model_two(input_shape=input_shape, num_classes=num_classes)
model2.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy',
               metrics=[top5])
history2 = model2.fit(train_x, train_y, epochs=50, batch_size=64, 
                      validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history2, 'Model2 Adam')

print("\nTraining model2 with sgd\n")
model2_sgd = build_model_two(input_shape=input_shape, num_classes=num_classes)
model2_sgd.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
                   loss='sparse_categorical_crossentropy',
                   metrics=[top5])
history2_sgd = model2_sgd.fit(train_x, train_y, epochs=50, batch_size=64, 
                              validation_data=(val_x, val_y), callbacks=[early_stop])
plot_history(history2_sgd, 'Model2 SGD')

#testing best models
print("\nEvaluating best models")
test_loss, test_acc = model2.evaluate(test_x, test_y)
print(f"Test accuracy: {test_acc:.4f}")


print("\nMaking predictions / plotting confusion matrix")
y_pred = np.argmax(model2.predict(test_x), axis=1)
plot_conf_matrix(test_y, y_pred, class_names)
# Out:
# 2025-07-10 15:29:54.845627: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2025-07-10 15:29:54.849966: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data
# Loading CIFAR100 data
# Validation size: 5000
# Train shape: (45000, 32, 32, 3)
# Val shape:  (5000, 32, 32, 3)
# test shape: (10000, 32, 32, 3)
# Training model1 with adam
# 2025-07-10 15:29:56.998077: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :
# 2025-07-10 15:29:56.998106: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-07-10 15:29:56.998124: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c2017.swan.hcc.unl.edu): /proc/driver/nvidia/version does not exist
# 2025-07-10 15:29:56.998376: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-10 15:29:57.015409: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2600000000 Hz
# 2025-07-10 15:29:57.016417: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f5b0061c60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-07-10 15:29:57.016440: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Epoch 1/50
# 704/704 [==============================] - 7s 10ms/step - loss: 4.2622 - sparse_top_5_categorical_accuracy: 0.1981 - val_loss: 3.7914 - val_sparse_top_5_categorical_accuracy: 0.3892
# Epoch 2/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.8458 - sparse_top_5_categorical_accuracy: 0.3427 - val_loss: 3.5261 - val_sparse_top_5_categorical_accuracy: 0.4788
# Epoch 3/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.6780 - sparse_top_5_categorical_accuracy: 0.3980 - val_loss: 3.3510 - val_sparse_top_5_categorical_accuracy: 0.5210
# Epoch 4/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.5794 - sparse_top_5_categorical_accuracy: 0.4326 - val_loss: 3.2752 - val_sparse_top_5_categorical_accuracy: 0.5438
# Epoch 5/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.5120 - sparse_top_5_categorical_accuracy: 0.4540 - val_loss: 3.2355 - val_sparse_top_5_categorical_accuracy: 0.5576
# Epoch 6/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.4458 - sparse_top_5_categorical_accuracy: 0.4730 - val_loss: 3.1910 - val_sparse_top_5_categorical_accuracy: 0.5688
# Epoch 7/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.4021 - sparse_top_5_categorical_accuracy: 0.4878 - val_loss: 3.0978 - val_sparse_top_5_categorical_accuracy: 0.5842
# Epoch 8/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.3632 - sparse_top_5_categorical_accuracy: 0.4976 - val_loss: 3.0689 - val_sparse_top_5_categorical_accuracy: 0.5982
# Epoch 9/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.3240 - sparse_top_5_categorical_accuracy: 0.5070 - val_loss: 3.0389 - val_sparse_top_5_categorical_accuracy: 0.6024
# Epoch 10/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.2832 - sparse_top_5_categorical_accuracy: 0.5229 - val_loss: 2.9961 - val_sparse_top_5_categorical_accuracy: 0.6178
# Epoch 11/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.2585 - sparse_top_5_categorical_accuracy: 0.5282 - val_loss: 2.9262 - val_sparse_top_5_categorical_accuracy: 0.6308
# Epoch 12/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.2417 - sparse_top_5_categorical_accuracy: 0.5309 - val_loss: 2.9298 - val_sparse_top_5_categorical_accuracy: 0.6354
# Epoch 13/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.2127 - sparse_top_5_categorical_accuracy: 0.5430 - val_loss: 2.9553 - val_sparse_top_5_categorical_accuracy: 0.6264
# Epoch 14/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1934 - sparse_top_5_categorical_accuracy: 0.5463 - val_loss: 2.8880 - val_sparse_top_5_categorical_accuracy: 0.6330
# Epoch 15/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1684 - sparse_top_5_categorical_accuracy: 0.5565 - val_loss: 2.9126 - val_sparse_top_5_categorical_accuracy: 0.6324
# Epoch 16/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1606 - sparse_top_5_categorical_accuracy: 0.5573 - val_loss: 2.8943 - val_sparse_top_5_categorical_accuracy: 0.6416
# Epoch 17/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1470 - sparse_top_5_categorical_accuracy: 0.5584 - val_loss: 2.9066 - val_sparse_top_5_categorical_accuracy: 0.6396
# Epoch 18/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1295 - sparse_top_5_categorical_accuracy: 0.5651 - val_loss: 2.8704 - val_sparse_top_5_categorical_accuracy: 0.6462
# Epoch 19/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1160 - sparse_top_5_categorical_accuracy: 0.5681 - val_loss: 2.8687 - val_sparse_top_5_categorical_accuracy: 0.6412
# Epoch 20/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0919 - sparse_top_5_categorical_accuracy: 0.5753 - val_loss: 2.8719 - val_sparse_top_5_categorical_accuracy: 0.6432
# Epoch 21/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0884 - sparse_top_5_categorical_accuracy: 0.5777 - val_loss: 2.8533 - val_sparse_top_5_categorical_accuracy: 0.6392
# Epoch 22/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0677 - sparse_top_5_categorical_accuracy: 0.5822 - val_loss: 2.8581 - val_sparse_top_5_categorical_accuracy: 0.6356
# Epoch 23/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0643 - sparse_top_5_categorical_accuracy: 0.5843 - val_loss: 2.8639 - val_sparse_top_5_categorical_accuracy: 0.6508
# Epoch 24/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0474 - sparse_top_5_categorical_accuracy: 0.5906 - val_loss: 2.8439 - val_sparse_top_5_categorical_accuracy: 0.6412
# Epoch 25/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0362 - sparse_top_5_categorical_accuracy: 0.5953 - val_loss: 2.8705 - val_sparse_top_5_categorical_accuracy: 0.6428
# Epoch 26/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0219 - sparse_top_5_categorical_accuracy: 0.5977 - val_loss: 2.8247 - val_sparse_top_5_categorical_accuracy: 0.6682
# Epoch 27/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0110 - sparse_top_5_categorical_accuracy: 0.5995 - val_loss: 2.8644 - val_sparse_top_5_categorical_accuracy: 0.6536
# Epoch 28/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0044 - sparse_top_5_categorical_accuracy: 0.6032 - val_loss: 2.7925 - val_sparse_top_5_categorical_accuracy: 0.6612
# Epoch 29/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9907 - sparse_top_5_categorical_accuracy: 0.6080 - val_loss: 2.8324 - val_sparse_top_5_categorical_accuracy: 0.6504
# Epoch 30/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9860 - sparse_top_5_categorical_accuracy: 0.6084 - val_loss: 2.8205 - val_sparse_top_5_categorical_accuracy: 0.6624
# Epoch 31/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9775 - sparse_top_5_categorical_accuracy: 0.6130 - val_loss: 2.8277 - val_sparse_top_5_categorical_accuracy: 0.6606
# Epoch 32/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9597 - sparse_top_5_categorical_accuracy: 0.6177 - val_loss: 2.8286 - val_sparse_top_5_categorical_accuracy: 0.6574
# Epoch 33/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9595 - sparse_top_5_categorical_accuracy: 0.6155 - val_loss: 2.8321 - val_sparse_top_5_categorical_accuracy: 0.6616
# Training model1 with sgd
#
# Epoch 1/50
# 704/704 [==============================] - 7s 10ms/step - loss: 4.6156 - sparse_top_5_categorical_accuracy: 0.1942 - val_loss: 4.2206 - val_sparse_top_5_categorical_accuracy: 0.2676
# Epoch 2/50
# 704/704 [==============================] - 7s 10ms/step - loss: 4.1439 - sparse_top_5_categorical_accuracy: 0.2832 - val_loss: 3.8323 - val_sparse_top_5_categorical_accuracy: 0.4054
# Epoch 3/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.8490 - sparse_top_5_categorical_accuracy: 0.3685 - val_loss: 3.5883 - val_sparse_top_5_categorical_accuracy: 0.4632
# Epoch 4/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.6225 - sparse_top_5_categorical_accuracy: 0.4323 - val_loss: 3.3677 - val_sparse_top_5_categorical_accuracy: 0.5158
# Epoch 5/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.4707 - sparse_top_5_categorical_accuracy: 0.4700 - val_loss: 3.2653 - val_sparse_top_5_categorical_accuracy: 0.5414
# Epoch 6/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.3517 - sparse_top_5_categorical_accuracy: 0.5036 - val_loss: 3.0635 - val_sparse_top_5_categorical_accuracy: 0.5856
# Epoch 7/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.2518 - sparse_top_5_categorical_accuracy: 0.5276 - val_loss: 2.9983 - val_sparse_top_5_categorical_accuracy: 0.6036
# Epoch 8/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.1662 - sparse_top_5_categorical_accuracy: 0.5509 - val_loss: 2.9485 - val_sparse_top_5_categorical_accuracy: 0.6232
# Epoch 9/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0974 - sparse_top_5_categorical_accuracy: 0.5725 - val_loss: 2.9043 - val_sparse_top_5_categorical_accuracy: 0.6310
# Epoch 10/50
# 704/704 [==============================] - 7s 10ms/step - loss: 3.0220 - sparse_top_5_categorical_accuracy: 0.5933 - val_loss: 2.8466 - val_sparse_top_5_categorical_accuracy: 0.6404
# Epoch 11/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9662 - sparse_top_5_categorical_accuracy: 0.6123 - val_loss: 2.8876 - val_sparse_top_5_categorical_accuracy: 0.6450
# Epoch 12/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.9100 - sparse_top_5_categorical_accuracy: 0.6218 - val_loss: 2.8222 - val_sparse_top_5_categorical_accuracy: 0.6518
# Epoch 13/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.8606 - sparse_top_5_categorical_accuracy: 0.6419 - val_loss: 2.8470 - val_sparse_top_5_categorical_accuracy: 0.6482
# Epoch 14/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.8271 - sparse_top_5_categorical_accuracy: 0.6530 - val_loss: 2.7816 - val_sparse_top_5_categorical_accuracy: 0.6668
# Epoch 15/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.7874 - sparse_top_5_categorical_accuracy: 0.6633 - val_loss: 2.7804 - val_sparse_top_5_categorical_accuracy: 0.6726
# Epoch 16/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.7353 - sparse_top_5_categorical_accuracy: 0.6779 - val_loss: 2.7637 - val_sparse_top_5_categorical_accuracy: 0.6784
# Epoch 17/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.7083 - sparse_top_5_categorical_accuracy: 0.6900 - val_loss: 2.8158 - val_sparse_top_5_categorical_accuracy: 0.6688
# Epoch 18/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.6749 - sparse_top_5_categorical_accuracy: 0.6995 - val_loss: 2.8206 - val_sparse_top_5_categorical_accuracy: 0.6736
# Epoch 19/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.6370 - sparse_top_5_categorical_accuracy: 0.7135 - val_loss: 2.7855 - val_sparse_top_5_categorical_accuracy: 0.6788
# Epoch 20/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.6164 - sparse_top_5_categorical_accuracy: 0.7218 - val_loss: 2.8305 - val_sparse_top_5_categorical_accuracy: 0.6820
# Epoch 21/50
# 704/704 [==============================] - 7s 10ms/step - loss: 2.6053 - sparse_top_5_categorical_accuracy: 0.7298 - val_loss: 2.8652 - val_sparse_top_5_categorical_accuracy: 0.6764
# Evaluating best models
# 313/313 [==============================] - 1s 2ms/step - loss: 2.7603 - sparse_top_5_categorical_accuracy: 0.6735
# Test accuracy: 0.6735
#
# Training model2 with adam
#
# Epoch 1/50
# 704/704 [==============================] - 16s 23ms/step - loss: 4.2118 - sparse_top_5_categorical_accuracy: 0.2978 - val_loss: 3.6861 - val_sparse_top_5_categorical_accuracy: 0.3936
# Epoch 2/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.6586 - sparse_top_5_categorical_accuracy: 0.4017 - val_loss: 3.3190 - val_sparse_top_5_categorical_accuracy: 0.5232
# Epoch 3/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.3786 - sparse_top_5_categorical_accuracy: 0.4898 - val_loss: 3.1050 - val_sparse_top_5_categorical_accuracy: 0.5778
# Epoch 4/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.1696 - sparse_top_5_categorical_accuracy: 0.5495 - val_loss: 2.8823 - val_sparse_top_5_categorical_accuracy: 0.6216
# Epoch 5/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.0197 - sparse_top_5_categorical_accuracy: 0.5908 - val_loss: 2.8560 - val_sparse_top_5_categorical_accuracy: 0.6358
# Epoch 6/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.9041 - sparse_top_5_categorical_accuracy: 0.6194 - val_loss: 2.7081 - val_sparse_top_5_categorical_accuracy: 0.6646
# Epoch 7/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.8109 - sparse_top_5_categorical_accuracy: 0.6438 - val_loss: 2.6406 - val_sparse_top_5_categorical_accuracy: 0.6936
# Epoch 8/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.7428 - sparse_top_5_categorical_accuracy: 0.6612 - val_loss: 2.6117 - val_sparse_top_5_categorical_accuracy: 0.6962
# Epoch 9/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.6693 - sparse_top_5_categorical_accuracy: 0.6784 - val_loss: 2.5580 - val_sparse_top_5_categorical_accuracy: 0.7002
# Epoch 10/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.6037 - sparse_top_5_categorical_accuracy: 0.6946 - val_loss: 2.5625 - val_sparse_top_5_categorical_accuracy: 0.7016
# Epoch 11/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.5481 - sparse_top_5_categorical_accuracy: 0.7088 - val_loss: 2.5165 - val_sparse_top_5_categorical_accuracy: 0.7200
# Epoch 12/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.4979 - sparse_top_5_categorical_accuracy: 0.7201 - val_loss: 2.5186 - val_sparse_top_5_categorical_accuracy: 0.7152
# Epoch 13/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.4578 - sparse_top_5_categorical_accuracy: 0.7307 - val_loss: 2.4785 - val_sparse_top_5_categorical_accuracy: 0.7274
# Epoch 14/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.4208 - sparse_top_5_categorical_accuracy: 0.7372 - val_loss: 2.4867 - val_sparse_top_5_categorical_accuracy: 0.7254
# Epoch 15/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3799 - sparse_top_5_categorical_accuracy: 0.7472 - val_loss: 2.4910 - val_sparse_top_5_categorical_accuracy: 0.7248
# Epoch 16/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3391 - sparse_top_5_categorical_accuracy: 0.7563 - val_loss: 2.4816 - val_sparse_top_5_categorical_accuracy: 0.7222
# Epoch 17/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3095 - sparse_top_5_categorical_accuracy: 0.7610 - val_loss: 2.4590 - val_sparse_top_5_categorical_accuracy: 0.7318
# Epoch 18/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.2656 - sparse_top_5_categorical_accuracy: 0.7728 - val_loss: 2.4421 - val_sparse_top_5_categorical_accuracy: 0.7380
# Epoch 19/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.2355 - sparse_top_5_categorical_accuracy: 0.7805 - val_loss: 2.4199 - val_sparse_top_5_categorical_accuracy: 0.7442
# Epoch 20/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.2189 - sparse_top_5_categorical_accuracy: 0.7836 - val_loss: 2.5443 - val_sparse_top_5_categorical_accuracy: 0.7196
# Epoch 21/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.1947 - sparse_top_5_categorical_accuracy: 0.7884 - val_loss: 2.4565 - val_sparse_top_5_categorical_accuracy: 0.7378
# Epoch 22/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.1549 - sparse_top_5_categorical_accuracy: 0.7970 - val_loss: 2.4886 - val_sparse_top_5_categorical_accuracy: 0.7314
# Epoch 23/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.1287 - sparse_top_5_categorical_accuracy: 0.8000 - val_loss: 2.4399 - val_sparse_top_5_categorical_accuracy: 0.7476
# Epoch 24/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.1140 - sparse_top_5_categorical_accuracy: 0.8047 - val_loss: 2.5000 - val_sparse_top_5_categorical_accuracy: 0.7330
# Training model2 with sgd
#
# Epoch 1/50
# 704/704 [==============================] - 16s 23ms/step - loss: 4.7977 - sparse_top_5_categorical_accuracy: 0.1972 - val_loss: 4.3533 - val_sparse_top_5_categorical_accuracy: 0.2780
# Epoch 2/50
# 704/704 [==============================] - 16s 23ms/step - loss: 4.2531 - sparse_top_5_categorical_accuracy: 0.2873 - val_loss: 3.9483 - val_sparse_top_5_categorical_accuracy: 0.3740
# Epoch 3/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.8810 - sparse_top_5_categorical_accuracy: 0.3860 - val_loss: 3.5483 - val_sparse_top_5_categorical_accuracy: 0.4710
# Epoch 4/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.5861 - sparse_top_5_categorical_accuracy: 0.4608 - val_loss: 3.3277 - val_sparse_top_5_categorical_accuracy: 0.5324
# Epoch 5/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.3595 - sparse_top_5_categorical_accuracy: 0.5178 - val_loss: 3.0811 - val_sparse_top_5_categorical_accuracy: 0.5878
# Epoch 6/50
# 704/704 [==============================] - 16s 23ms/step - loss: 3.1578 - sparse_top_5_categorical_accuracy: 0.5648 - val_loss: 2.9819 - val_sparse_top_5_categorical_accuracy: 0.6098
# Epoch 7/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.9902 - sparse_top_5_categorical_accuracy: 0.6065 - val_loss: 2.8166 - val_sparse_top_5_categorical_accuracy: 0.6444
# Epoch 8/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.8534 - sparse_top_5_categorical_accuracy: 0.6388 - val_loss: 2.7697 - val_sparse_top_5_categorical_accuracy: 0.6576
# Epoch 9/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.7342 - sparse_top_5_categorical_accuracy: 0.6676 - val_loss: 2.6886 - val_sparse_top_5_categorical_accuracy: 0.6788
# Epoch 10/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.6300 - sparse_top_5_categorical_accuracy: 0.6933 - val_loss: 2.6041 - val_sparse_top_5_categorical_accuracy: 0.6960
# Epoch 11/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.5519 - sparse_top_5_categorical_accuracy: 0.7168 - val_loss: 2.6566 - val_sparse_top_5_categorical_accuracy: 0.6910
# Epoch 12/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.4659 - sparse_top_5_categorical_accuracy: 0.7354 - val_loss: 2.6183 - val_sparse_top_5_categorical_accuracy: 0.7086
# Epoch 13/50
# 704/704 [==============================] - 16s 22ms/step - loss: 2.3969 - sparse_top_5_categorical_accuracy: 0.7564 - val_loss: 2.5920 - val_sparse_top_5_categorical_accuracy: 0.7164
# Epoch 14/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3459 - sparse_top_5_categorical_accuracy: 0.7711 - val_loss: 2.6074 - val_sparse_top_5_categorical_accuracy: 0.7160
# Epoch 15/50
# 704/704 [==============================] - 16s 22ms/step - loss: 2.2881 - sparse_top_5_categorical_accuracy: 0.7877 - val_loss: 2.6388 - val_sparse_top_5_categorical_accuracy: 0.7114
# Epoch 16/50
# 704/704 [==============================] - 16s 22ms/step - loss: 2.2350 - sparse_top_5_categorical_accuracy: 0.8015 - val_loss: 2.6741 - val_sparse_top_5_categorical_accuracy: 0.7142
# Epoch 17/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.1988 - sparse_top_5_categorical_accuracy: 0.8131 - val_loss: 2.7047 - val_sparse_top_5_categorical_accuracy: 0.7202
# Epoch 18/50
# 704/704 [==============================] - 16s 23ms/step - loss: 2.1603 - sparse_top_5_categorical_accuracy: 0.8243 - val_loss: 2.7010 - val_sparse_top_5_categorical_accuracy: 0.7230
# Evaluating best models
# 313/313 [==============================] - 1s 4ms/step - loss: 2.4059 - sparse_top_5_categorical_accuracy: 0.7449
# Test accuracy: 0.7449
#
# Making predictions / plotting confusion matrix
